# %%
import os, sys
print(sys.path)
# Out:
# ['C:\\Users\\joelj\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\joelj\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\joelj\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\joelj\\AppData\\Local\\Programs\\Python\\Python313', 'D:\\Projects\\PowerBI\\venv_pbi', '', 'D:\\Projects\\PowerBI\\venv_pbi\\Lib\\site-packages']

# %%
import sys
print(sys.executable)
# Out:
# D:\Projects\PowerBI\venv_pbi\Scripts\python.exe

# %%
# !D:/Projects/PowerBI\venv_pbi/Scripts/python.exe -m pip install matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_0 = pd.read_csv('D:/Projects/PowerBI/Vehicle_prices_aus/aus_vehicle_prices_cleaned.csv')

# %%
df_0
# Out:
#        Unnamed: 0    brand    year   model used_or_new transmission  \
# 0               0  Hyundai  2015.0  Tucson        USED    Automatic
# 1               1  Hyundai  2020.0  Tucson        USED    Automatic
# 2               2  Hyundai  2019.0  Tucson        USED    Automatic
# 3               3  Hyundai  2018.0  Tucson        USED    Automatic
# 4               4  Hyundai  2019.0  Tucson        USED    Automatic
# ...           ...      ...     ...     ...         ...          ...
# 16665       16665      BMW  2015.0    225I        USED    Automatic
# 16666       16666      Kia  2014.0     RIO        USED       Manual
# 16667       16667    Honda  1998.0   Civic        USED    Automatic
# 16668       16668     Alfa  2014.0   Romeo        USED    Automatic
# 16669       16669   Toyota  2008.0   Yaris        USED       Manual
#
#       drive_type fuel_type fuel_consumption  kilometres  cylinders  body_type  \
# 0          Front  Unleaded   7.9 L / 100 km     94377.0        4.0        SUV
# 1          Front  Unleaded   7.9 L / 100 km     38341.0        4.0        SUV
# 2          Front  Unleaded   7.9 L / 100 km    104066.0        4.0        SUV
# 3          Front  Unleaded   7.9 L / 100 km     88501.0        4.0        SUV
# 4          Front  Unleaded   7.9 L / 100 km     23126.0        4.0        SUV
# ...          ...       ...              ...         ...        ...        ...
# 16665      Front   Premium   6.1 L / 100 km     46232.0        4.0  Hatchback
# 16666      Front  Unleaded   5.6 L / 100 km    231137.0        4.0  Hatchback
# 16667      Front  Unleaded   8.4 L / 100 km    206276.0        4.0  Hatchback
# 16668      Front   Premium   5.5 L / 100 km    215977.0        4.0  Hatchback
# 16669      Front  Unleaded     6 L / 100 km     35000.0        4.0  Hatchback
#
#        doors  seats    price  cylinder_capacity exterior_clr          suburb  \
# 0        4.0    5.0  23888.0                2.0         Grey   Mcgraths Hill
# 1        4.0    5.0  28984.0                2.0         Blue       Granville
# 2        4.0    5.0  26990.0                2.0        White       Singleton
# 3        4.0    5.0  26495.0                2.0       Silver         Berwick
# 4        4.0    5.0  34990.0                2.0        Black    Warwick Farm
# ...      ...    ...      ...                ...          ...             ...
# 16665    4.0    5.0  28990.0                2.0         Blue       Five Dock
# 16666    3.0    5.0  10499.0                1.4        White        Ringwood
# 16667    3.0    5.0   7387.0                1.6       Silver        Ringwood
# 16668    3.0    5.0   8999.0                1.4         Grey  Laverton North
# 16669    3.0    5.0  11990.0                1.3          NaN       Toowoomba
#
#       state
# 0       NSW
# 1       NSW
# 2       NSW
# 3       VIC
# 4       NSW
# ...     ...
# 16665   NSW
# 16666   VIC
# 16667   VIC
# 16668   VIC
# 16669   QLD
#
# [16670 rows x 19 columns]

# %%
new_names = {'Car/Suv':'segment','Brand': 'brand', 'Year': 'year', 'Model':'model', 'Vehicle_type':'vehicle_type', 'Title':'title', 'UsedOrNew':'used_or_new', 'Transmission':'transmission', 'Engine':'engine', 'DriveType':'drive_type', 'FuelType':'fuel_type', 'FuelConsumption':'fuel_consumption', 'Kilometres':'kilometres', 'ColourExtInt':'color_ext_int', 'Location': 'location', 'CylindersinEngine': 'cylinders','BodyType':'body_type', 'Doors':'doors','Seats':'seats','Price': 'price'}
df = df_0.rename(columns=new_names)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'year', 'model', 'used_or_new', 'transmission',
#        'drive_type', 'fuel_type', 'fuel_consumption', 'kilometres',
#        'cylinders', 'body_type', 'doors', 'seats', 'price',
#        'cylinder_capacity', 'exterior_clr', 'suburb', 'state'],
#       dtype='object')

# %% [markdown]
# ## Analysing 'Used_or_new' column
# 1. New cars are from the year 2022 and 2023

# %%
new_cars = df_0.loc[df_0['used_or_new']=='NEW','year']
new_cars.groupby(new_cars.values).count()
# df['used_or_new'].groupby(df['used_or_new'].values).count()
# Out:
# 2011.0      1
# 2022.0    214
# 2023.0    842
# Name: year, dtype: int64

# %%
new_cars = df_0.loc[df_0['used_or_new']=='NEW','kilometres']
new_cars.describe()
# new_cars.groupby(new_cars.values).count()
# Out:
# count      1057.000000
# mean        200.157048
# std        5998.700794
# min           1.000000
# 25%          14.000000
# 50%          14.000000
# 75%          14.000000
# max      195040.000000
# Name: kilometres, dtype: float64

# %%
new_cars.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Column brand

# %%
df['brand'].unique()

# %%
type(df['brand'])

# %% [markdown]
# ## Column Year

# %%
df['year'].unique()

# %% [markdown]
# ## Column model

# %%
df['model'].unique()

# %%
df['model'].isna().sum()

# %% [markdown]
# ## Column segment

# %%
df['segment'].unique()

# %%
segment_count = df['segment'].groupby(df['segment'].values).count()
segment_count

# %%
df['segment'].values

# %%
segment_count.sort_values(ascending=False)[:15]

# %%
# dropping the segmwnt column because its not very useful
df = df.drop(labels = 'segment', axis = 1)
df

# %% [markdown]
# ## Column title

# %%
df['title']

# %%
df = df.drop( labels = 'title', axis=1 )
df

# %% [markdown]
# ## Column used_or_new

# %%
df.columns

# %%
df['used_or_new']

# %%
df['used_or_new'].unique()

# %% [markdown]
# ## Column transmission

# %%
df['transmission'].unique()

# %%
df.loc[df['transmission']== '-']

# %%
df['transmission'] = df['transmission'].replace(to_replace='-' ,value=np.nan)

# %%
df.loc[df['transmission']== '-']

# %%
type(df.loc[df['transmission'].isna()]['transmission'][6340]) # checking for correct change to nan

# %% [markdown]
# ## Column engine

# %%
df['engine']

# %%
# # Checking if all values in the col are of the regex of num of cylinders and capacity in litres
df['engine'].str.fullmatch(r'\d{1,2} cyl, \d+(?:\.\d+)? L').all()

# %%
# What are the values that dont conform to the pattern
df.loc[ ~df['engine'].str.fullmatch(r'\d{1,2} cyl, \d+(?:\.\d+)? L')]['engine'].unique()

# %%
# 1763 messy rows in engine column
df.loc[ ~df['engine'].str.fullmatch(r'\d{1,2} cyl, \d+(?:\.\d+)? L')]['engine'].count()

# %%
# Which entries have engine 0l but non electric engine
df.loc[(df['engine'] == '0 L') & ~(df['fuel_type'] == 'Electric')]

# Google search shows NISSAN LEAF is an electric car.

# %%
# Change entry 7936 engine value to NaN
df.loc[7936, 'engine'] = np.nan
df['engine'][7936]

# %%
# Changing all -'s to NaN'
df.loc[(df['engine'] == '-')] = np.nan

# %%
# Entry 6637 
df.loc[df['engine'] =='4 cyl']

# %%
# ENTRY  10029 
df.loc[df['engine'] =='2 L']

# %% [markdown]
# ## Column cylinder_capacity

# %%
cyl_capacity = pd.Series()

# %%
cyl_capacity = df['engine'].str.strip().str.extract(r'[\s,]+(\d*\.?\d+)\s*L\b', expand=False).astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cyl_capacity = df['engine'].str.strip().str.extract(r'[\s,]+(\d*\.?\d+)\s*L\b', expand=False).astype(float)
#
# NameError: name 'df' is not defined

# %%
cyl_capacity.isna().sum() # We have 1763 NaN values consistent with the count we found not following the regex patterm
# Out:
# np.int64(0)

# %%
df['cylinder_capacity'] = cyl_capacity
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df['cylinder_capacity'] = cyl_capacity
#
# NameError: name 'df' is not defined

# %%
df.drop(labels='engine', axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.drop(labels='engine', axis=1,inplace=True)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Column drive_type

# %%
df['drive_type'].unique()

# %%
df.loc[df['drive_type'] == 'Other']

# %%
df['drive_type'] = df['drive_type'].replace(to_replace='Other' ,value=np.nan)

# %%
df['drive_type'].unique()

# %% [markdown]
# ## Column fuel_type
#
# entry #7936 nissan leaf is electric

# %%
df['fuel_type'].unique()

# %%
# Change missing values to nan
df['fuel_type'] = df['fuel_type'].replace(to_replace = '-', value = np.nan)
df['fuel_type'].unique()

# %% [markdown]
# ## Column fuel_consumption

# %%
df['fuel_consumption']

# %%
# Check sanity
df['fuel_consumption'].str.fullmatch(r'(\d+(?:\.\d+)?)\s*L\s*/\s*100\s*km').all()

# %%
df['fuel_consumption'].str.fullmatch(r'(\d+(?:\.\d+)?)\s*L\s*/\s*100\s*km')

# %%
pattern_conforming_boolean = df['fuel_consumption'].str.fullmatch(r'(\d+(?:\.\d+)?)\s*L\s*/\s*100\s*km').astype('bool')

# %%
df['fuel_consumption'].loc[(~pattern_conforming_boolean)].unique()

# %%
df['fuel_consumption'] = df['fuel_consumption'].replace(to_replace='-', value = np.nan)

# %%
df['fuel_consumption'].loc[(~pattern_conforming_boolean)].unique()

# %% [markdown]
# ## Column kilometres

# %%
df['kilometres']

# %%
(df['kilometres'] > 0).pipe(all)

# %% [markdown]
# ## Column color_ext_int

# %%
df['color_ext_int']

# %%
df[['exterior_clr', 'interior_clr']]  = df['color_ext_int'].str.extract(r'^\s*(.*?)\s*\/\s*(.*?)\s*$')

# %%
df['exterior_clr'].unique()

# %%
non_colors = {'-', 'Other', '5 years', '3 years', '7 years', '2 years',
              '1 years', '6 years', '4 years'}

df['exterior_clr'] = df['exterior_clr'].replace( to_replace = non_colors, value = np.nan )

df['exterior_clr'].unique()

# %%
df['interior_clr'].unique()

# %%
df['interior_clr'].groupby(df['interior_clr'].values).count().sort_values(ascending=False)

# %%
df.drop(labels='color_ext_int', axis = 1, inplace=True)

# %% [markdown]
# ## Column Interior Color

# %%
df['interior_clr'].groupby(df['interior_clr'].values).count().sort_values(ascending=False)[:10]

# %%
df.drop(labels='interior_clr',axis=1, inplace=True )

# %%
df.columns

# %% [markdown]
# ## Column location

# %%
df['location']

# %%
# Extracts two new columns: suburb and state
df[['suburb', 'state']] = df['location'].str.extract(r'^\s*(.+?),\s*([A-Z]{2,})\s*$')

# %%
df['state']

# %%
df['suburb']

# %%
df.drop(labels='location', axis=1, inplace=True)

# %% [markdown]
# ## Column Cylinders

# %%
df['cylinders']

# %%
df['cylinders'].unique()

# %%
invalid_values = {'0 L', '2 L'}
df['cylinders'] = df['cylinders'].replace( to_replace = invalid_values, value = np.nan )
df['cylinders'].unique()

# %%
df['cylinders'] = df['cylinders'].str.extract(r'(\d+)')
df['cylinders']

# %%
df['cylinders'].unique()

# %% [markdown]
# ## Column body_type

# %%
df['body_type'].unique()

# %%
df['body_type'].unique()[-1]

# %%
df['body_type'] = df['body_type'].replace(to_replace = 'Ute / Tray', value='Ute')

# %%
df['body_type'].unique()

# %% [markdown]
# ## Column Doors

# %%
df['doors'] = df['doors'].str.extract(r'(\d+)')

# %%
df['doors'].unique()

# %% [markdown]
# ## Column Seats

# %%
df['seats'].unique()

# %%
df['seats'] = df['seats'].str.extract(r'(\d+)')

# %%
df['seats'].unique()

# %% [markdown]
# ## Column price

# %%
df['price']

# %%
df['price'].isna().sum()

# %%
df

# %% [markdown]
# ## Serialization of data

# %%
df.to_csv('D:/Projects/PowerBI/Vehicle_prices_aus/aus_vehicle_prices_cleaned.csv')

# %% [markdown]
# ## Top models in top brand

# %%
df['brand'].groupby(df['brand'].values).count().sort_values(ascending=False).nlargest()
# Out:
# Toyota           2313
# Hyundai          1165
# Mazda            1098
# Holden           1024
# Ford              975
# Mitsubishi        965
# Nissan            856
# Volkswagen        808
# Kia               775
# Mercedes-Benz     551
# Name: brand, dtype: int64

# %%
type(df.loc[df['brand'] == 'Toyota', 'model'])
# Out:
# pandas.core.series.Series

# %%
model_series = df.loc[df['brand'] == 'Toyota', 'model']

# %%
model_series.groupby(model_series.values).count().nlargest(7)
# Out:
# Hilux          413
# Landcruiser    369
# Corolla        361
# RAV4           344
# Camry          220
# Kluger         156
# Yaris          112
# Name: model, dtype: int64
